# %% [markdown]
# # My Jupyter Notebook

# %% [markdown]
# ## Exercise 3: Introduction
# This notebook contains basic exercises for practicing Markdown and Python code in a Jupyter Notebook environment

# %% [markdown]
# ## Exercise 4: Data Science Languages
# - Python
# - R
# - SQL
# - Julia`
# - Scala

# %% [markdown]
# ## Exercise 5: Data Science Libraries
# - NumPy
# - Pandas
# - Matplotlib
# - Scikit-learn
# - TensorFlow
# - Keras

# %% [markdown]
# ## Exercise 6: Data Science Tools
#
# | Tool | Description |
# |------|-------------|
# | Jupyter Notebook | Interactive development environment |
# | RStudio | IDE for R programming |
# | Apache Spark | Big data processing engine |
# | TensorFlow | Machine learning framework |
# | Tableau | Data visualization tool |

# %% [markdown]
# ## Exercise 7: Examples of Arithmetic Expressions
# Below are examples of basic arithmetic expressions using Python.

# %%
# Exercise 8: Multiply and add numbers
a = 5 * 6
b = a + 10
b
# Out:
# 40

# %%
# Exercise 9: Convert minutes to hours
minutes = 150
hours = minutes / 60
hours
# Out:
# 2.5

# %% [markdown]
# ## Exercise 10: Objectives
# - Demonstrate basic Markdown usage
# - Use Python code cells
# - Perform arithmetic operations
# - Create tables in Markdown
# - Practice notebook formatting

# %% [markdown]
# ## Exercise 11: Author
# Giang
